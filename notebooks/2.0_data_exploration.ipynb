# %% [markdown]
# # Data Exploration
#
# ## Purpose: Explore data tounderstand how to perform different operations

# %%
from pathlib import Path

import pandas as pd

# %%
p_ext_data = Path("../data/01_external")

# %%
df_prod = pd.read_parquet(p_ext_data.joinpath("production.parquet"))
df_comp = pd.read_parquet(p_ext_data.joinpath("completion.parquet"))

# %%
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372530 entries, 0 to 372529
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   idempresa               372530 non-null  object
#  1   anio                    372530 non-null  int64
#  2   mes                     372530 non-null  int64
#  3   idpozo                  372530 non-null  int64
#  4   prod_pet                372530 non-null  float64
#  5   prod_gas                372530 non-null  float64
#  6   prod_agua               372530 non-null  float64
#  7   iny_agua                372530 non-null  float64
#  8   iny_gas                 372530 non-null  float64
#  9   iny_co2                 372530 non-null  float64
#  10  iny_otro                372530 non-null  float64
#  11  tef                     372530 non-null  float64
#  12  vida_util               7807 non-null    float64
# ...

# %%
df_prod.head(5)
# Out:
#   idempresa  anio  mes  idpozo  prod_pet  prod_gas  prod_agua  iny_agua  \
# 0      YSUR  2018    1  132491     5.466   131.734       3.81       0.0
# 1      YSUR  2017    1  130022     0.000   182.600       9.23       0.0
# 2      YSUR  2018    1  132489     2.201   164.605       7.03       0.0
# 3      YSUR  2017    1  135208     0.000   105.300       0.00       0.0
# 4      YSUR  2018    1  132488     0.000   171.937       0.00       0.0
#
#    iny_gas  iny_co2  ...    cuenca  provincia  coordenadax coordenaday  \
# 0      0.0      0.0  ...  NEUQUINA    Neuquén   -69.183251  -39.083192
# 1      0.0      0.0  ...  NEUQUINA    Neuquén   -69.720525  -39.008460
# 2      0.0      0.0  ...  NEUQUINA  Rio Negro   -67.865009  -39.016697
# 3      0.0      0.0  ...  NEUQUINA    Neuquén   -69.715565  -39.007522
# 4      0.0      0.0  ...  NEUQUINA  Rio Negro   -67.864960  -39.016722
#
#    tipo_de_recurso  proyecto clasificacion subclasificacion  sub_tipo_recurso  \
# ...

# %%
# Basic profiling
print("Shape:", df_prod.shape)
print("\nColumn types:\n", df_prod.dtypes)
print("\nMissing values:\n", df_prod.isnull().sum())
print("\nUnique values per column:\n", df_prod.nunique())
# Out:
# Shape: (372530, 40)
#
# Column types:
#  idempresa                  object
# anio                        int64
# mes                         int64
# idpozo                      int64
# prod_pet                  float64
# prod_gas                  float64
# prod_agua                 float64
# iny_agua                  float64
# iny_gas                   float64
# iny_co2                   float64
# iny_otro                  float64
# tef                       float64
# vida_util                 float64
# tipoextraccion             object
# tipoestado                 object
# tipopozo                   object
# observaciones              object
# fechaingreso               object
# rectificado                  bool
# habilitado                   bool
# idusuario                   int64
# empresa                    object
# sigla                      object
# formprod                   object
# profundidad               float64
# formacion                  object
# ...

# %%
df_prod["idareayacimiento"].head(10)
# Out:
# 0     RQC
# 1    ANCS
# 2    Z155
# 3    ANCS
# 4    Z155
# 5     RQC
# 6    Z155
# 7     ACO
# 8     ACO
# 9    Z155
# Name: idareayacimiento, dtype: object

# %%
for col in df_prod.columns:
    text = f"""- {col} -
{df_prod[col].value_counts()}

    """
    print(text)
# Out:
# - idempresa -
# idempresa
# YPF     205517
# PLU      19515
# APS      19466
# PAL      16956
# TAU      14233
# CGC      13749
# TPT      13154
# PAM      11241
# YSUR      7721
# SHE       7295
# PBE       6595
# APEA      6448
# VST       5678
# PAE       4827
# OILS      3833
# EMEA      2578
# CHE       1645
# QUIN      1564
# PTRE      1506
# KILW      1373
# VIS       1228
# PEL        911
# OGDV       896
# PPSA       535
# PCR        518
# WIN        412
# WDA        392
# PCN        330
# ENE1       270
# FXS        262
# AME        233
# BEN        232
# MSA        219
# ACO        202
# CG1        193
# VOG        140
# AESA       132
# ROC        106
# GTIE        81
# GPNE        79
# PES         72
# GREC        59
# MAD         31
# VNO         31
# APGA        28
# CNA         20
# GGO         13
# PSE         11
# Name: count, dtype: int64
#
#
# - anio -
# anio
# 2024    48439
# 2023    43219
# 2025    40094
# 2022    38918
# 2021    34506
# 2020    31716
# ...
